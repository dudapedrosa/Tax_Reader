# %% [markdown]
# # DOCUMENTAÇÃO DO CÓDIGO

# %% [markdown]
# ## ESTRUTURA DO CODE

# %% [markdown]
# - OBJETIVO GERAL

# %% [markdown]
# - FUNCIONALIDADES

# %% [markdown]
# - DESIGN

# %% [markdown]
# - MODO DE USO:
# -> Site interativo via streamlit
# -> Aplicativo executável
